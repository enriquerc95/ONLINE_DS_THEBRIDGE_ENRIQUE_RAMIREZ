# %% [markdown]
# TEORÍA Y COMANDOS DATA SCIENCE
#
# MARKDOW
#
# N
# Image
# n:
# La imagen tiene que estar en la misma carpeta que este notebook, debido a la sintaxis ./imagen.png. Con el ./ Jupyter entiende que tiene que buscar en la carpeta de este notebo
#
# ok:
# 1.	./imagen.png si la imagen esta en el mismo directorio donde está este Note
#
#    b3ok
# 2.	./img/imagen.png si dentro del directorio donde se encuentra este Notebook, hay una carpeta llamada "img", y dentro se encuentra la im
#
#    agen.
# PYTHON

# %%
variabe = "Esto es una variable"

#Funciones:

#Hay una serie de funciones internas, que vienen en el intérprete de Python. Algunas de las más comunes son:
#•	Tipos: bool(), str(), int(), float()
#•	Min/Max: min(), max()
#•	print()
#•	type()
#•	range()
#•	zip()
#•	len()
3•	...
#La sintaxis de la función es:
#nombre_funcion(argumentos)
#Len se usa para calcular la longitud de una variable. 
print(len("Esto es una cadena de longitud..."))
#Funcion max. Tiene tantos argumentos como cantidad de números entre los cuales queramos sacar su valor máximo.
print(max(1,12,24,25,6))

cadena = "la longitud de esta cadena es"
print(cadena,len(cadena),"y no es un float",sep = "**test**")


Métodos:
funciones propias de las variables/objetos, y que nos permiten modificarlos u obtener más información de los mismos.
Para usar un método se usa la sintaxis objeto.metodo()
Método en string:
string_ejemplo = "string en minusculas"
#metodo string en mayus
print(string_ejemplo.upper())
string_ejemplo
#metodo en minusculas
print("ESTO ES UN EJEMPLO DIFERENTE".lower())
string_ejemplo_2 ="ESTO ES UN EJEMPLO DIFERENTE"
print(string_ejemplo_2.lower())

Método para reemplazar algún caracter o varios
print(string_ejemplo.replace("s","c"))
print(string_ejemplo.replace("minusculas", "minúsculas"))
print(string_ejemplo.replace("s", ""))

Método convertir string en lista
print("Esto se va a convertir en una lista de strings".split(" "))#Método para conocer la posición dentro de un string
Método para conocer la posición dentro de un string
print(string_ejemplo.index("m"))










LISTAS:
Nos permiten almacenar conjuntos de variables u objetos, y son elementos de lo más versátiles puesto que podemos almacenar objetos de distintos tipos, modificarlos, eliminarlos, meter listas dentro de listas... Sus dos caractrísticas principales son:
•	Mutables: una vez se ha creado la lista, se puede modificar
•	Ordenada: Los elementos tienen un cierto orden, lo que nos permite acceder al elemento que queramos teniendo en cuenta tal orden
 Lista numeros 
numeros = [1,2,3,5,6]
print(type(numeros))
[1, 2, 3, 5, 6]
<class 'list'>

Lista strings
strings = ["esto", "es","lista"]
print(strings)
Lista booleanos
bool = [True, False, not False, True or False, False and False]
print(bool)
Pueden ser mezcladas
mix = ["Esto", 12, -32.5, True]
lista = ["g", 2, True, [1,2,3]]
len(lista) #para saber el número de elementos de la lista
Concatenaciones
conc = mix + lista
print(conc)
print(type(conc))

MÉTODOS
Saber el tipo
type(conc) 
Longitud de la lista
len() 
asignaturas = ["física", "química", "mates", "literatura"]
Añadir elemento a una lista
asignaturas.append("Filosofía")

Añadir elementois en posición determinada
asignaturas.insert(1, "Gimnasia")

Quitar elementos
asignaturas.clear()

Quitar un elemento a partir de su índice o posición
asignaturas.pop(1)

Quitar un elemento por su valor
asignaturas.remove("Filosofía")

Ordenar la lista
asignaturas.sort()

ACCESO A LISTAS
Entre corchetes introducimos el indice del elemento al que queremos acceder:
months = ["Enero", "Febrero", "Marzo"]
print(months[0]) ENERO
print(months[-1]) MARZO
Obtener el índice de esos valores dentro de la lista:
months = ["Enero", "Febrero", "Marzo", "Marzo"]
print(months.index("Febrero")) 1
print(months.index("Marzo")) 2
Slicing
usamos slicing para acceder a varios elementos seguidos de la lista
degrees = [22, 34, 15, 26, 18, 22]
sub_degrees = degrees[1:3]
print(sub_degrees) [34, 15]
sub_degrees_alt = degrees[1:len(degrees)]
sub_degrees_alt2 = degrees[1:]
print(sub_degrees_alt) [34, 15, 26, 18, 22]
print(sub_degrees_alt2) [34, 15, 26, 18, 22]
MODIFICAR ELEMENTOS
Las listas son mutables, por lo que podremos modificarlas
Accediendo mediante el indice
months = ["Enero", "Febrero", "Marzo"]
months[1] = "Abril"
print(months) ['Enero', 'Abril', 'Marzo']
AÑADIR ELEMENTOS
append lo añadimos al final de la lista:
motorcycles = ['honda', 'yamaha', 'suzuki']
motorcycles.append("Kawasaki")
print(motorcycles) ['honda', 'yamaha', 'suzuki', 'Kawasaki']
insert sirve para elegir en que posición se añaden
motorcycles.insert(3,"bultaco")
print(motorcycles) ['honda', 'yamaha', 'suzuki', 'bultaco', 'Kawasaki']

ELIMINAR ELEMENTOS
# Out:
#   Cell In[1], line 13
#     3•	...
#     ^
# SyntaxError: invalid decimal literal
